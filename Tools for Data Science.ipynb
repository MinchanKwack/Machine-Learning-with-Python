# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Minchan Kwack**
#
# Data Scientist

# %% [markdown]
# _I am interested in Data Science because I want to use data in shopping application in the future_

# %% [markdown]
# ### The below should print '1+1'

# %%
print("1+1")
# Out:
# 1+1

# %% [markdown]
# > My favorite soccer player
# >
#  - Heungmin Son
#  - Jisung Park
#
# <hr>
#
# Made with <3 [My Github](https://github.com/Thomas-George-T)
